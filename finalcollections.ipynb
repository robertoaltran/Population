# %%
import pandas as pd
import requests
import time
import threading
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import WebDriverException

# %%
pip install beautifulsoup4 selenium
# Out:
# Requirement already satisfied: beautifulsoup4 in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (4.10.0)
# Requirement already satisfied: selenium in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (4.14.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4) (2.2.1)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from selenium) (1.26.7)
# Requirement already satisfied: certifi>=2021.10.8 in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from selenium) (2021.10.8)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from selenium) (0.11.1)
# Requirement already satisfied: trio~=0.17 in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from selenium) (0.22.2)
# Requirement already satisfied: sniffio in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=20.1.0 in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (21.2.0)
# Requirement already satisfied: outcome in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: idna in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (3.2)
# Requirement already satisfied: sortedcontainers in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.1.3)
# Requirement already satisfied: wsproto>=0.14 in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install selenium --upgrade
# Out:
# Requirement already satisfied: selenium in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (4.14.0)
# Requirement already satisfied: certifi>=2021.10.8 in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from selenium) (2021.10.8)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from selenium) (0.11.1)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from selenium) (1.26.7)
# Requirement already satisfied: trio~=0.17 in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from selenium) (0.22.2)
# Requirement already satisfied: outcome in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.1.3)
# Requirement already satisfied: attrs>=20.1.0 in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (21.2.0)
# Requirement already satisfied: sniffio in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: idna in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (3.2)
# Requirement already satisfied: sortedcontainers in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: wsproto>=0.14 in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Collecting Data Processing
#
# To develop the machine learning model and obtain the data for the training set, information from the real estate website was used. This was because certain characteristics of the properties were essential. However, since this information wasn't already tabulated, web scraping techniques were employed, such as the Selenium library. Below are the details on how it was developed.
#
#
# ## First Step
#
# The next script is designed to gather property links from a real estate website using automated web browsing tools, specifically a library called Selenium. This lets the program act like a person using a web browser, scrolling through pages, waiting for new content to appear, and then grabbing the links to properties.
#
# The program is smart enough to handle lots of pages efficiently. Instead of going through each page one by one, it can work on several pages at the same time. This is done using something called multithreading, which is like having multiple hands all working together. And if the program runs into any problems, like a page not loading properly, it will try again a few times before moving on.
#
# Once all the property links are collected, the program shows them so you can see the results. This makes it easy to check the work and use those links for other things later on.

# %%
MAX_RETRIES = 3

def extract_links(driver):
    links = []

    max_scrolls = 20
    scrolls = 0

    driver.execute_script("window.scrollTo(0, document.body.scrollHeight/2);")
    time.sleep(20)

    while True:
        try:
            house_links_elements = driver.find_elements(By.CSS_SELECTOR, "a.ember-view.listing-tile-info")

            for link in house_links_elements:
                link_href = link.get_attribute('href')
                if link_href not in links:
                    links.append(link_href)

            if len(links) >= 10:
                break

            driver.execute_script("window.scrollBy(0, 500);")
            time.sleep(3)

            scrolls += 1
            if scrolls >= max_scrolls:
                break

        except WebDriverException:
            return []

    return links

def extract_links_from_pages(driver, start_page, end_page):
    all_links = []
    base_url = 'https://www.realestate.co.nz/residential/rental/auckland/auckland-city?by=oldest'
    driver.execute_script("document.body.style.zoom = '0.5'")
    for i in range(start_page, end_page + 1):
        retries = 0
        success = False
        while retries < MAX_RETRIES and not success:
            try:
                if i > 1:
                    url = f"{base_url}&page={i}"
                else:
                    url = base_url
                driver.get(url)
                page_links = extract_links(driver)
                all_links.extend(page_links)
                print(f"Extracted {len(page_links)} links from page {i}")
                success = True
            except WebDriverException:
                retries += 1
                print(f"Error loading page {i}. Retrying ({retries}/{MAX_RETRIES})...")
                if retries == MAX_RETRIES:
                    print(f"Failed to load page {i} after {MAX_RETRIES} retries. Moving to next page.")

    return all_links

def start_extraction_thread(start_page, end_page):
    options = webdriver.ChromeOptions()
    prefs = {
        "profile.managed_default_content_settings.images": 2,
        "profile.default_content_setting_values.notifications": 2,
        "profile.default_content_setting_values.popups": 2
    }
    options.add_experimental_option("prefs", prefs)
    options.add_argument("--disable-popup-blocking")

    while start_page <= end_page:
        try:
            driver = webdriver.Chrome(options=options)
            driver.set_script_timeout(300)
            links = extract_links_from_pages(driver, start_page, end_page)
            for link in links:
                print(link)
            driver.quit()
            break  # Exit the loop if extraction was successful
        except WebDriverException:
            print("Driver crashed. Restarting...")
            start_page = end_page  # Adjust the start_page if needed

if __name__ == "__main__":
    t1 = threading.Thread(target=start_extraction_thread, args=(1, 20))
    t2 = threading.Thread(target=start_extraction_thread, args=(21, 40))

    t1.start()
    t2.start()

    t1.join()
    t2.join()

# %%
url = 'https://raw.githubusercontent.com/robertoaltran/Population/main/links.txt'
response = requests.get(url)
sites = response.text.splitlines()
sites = [site.strip() for site in sites]

# %%
quantity_elements = len(sites)
print("Elements:", quantity_elements)
# Out:
# Elements: 405

# %%
sites.sort()

# %%
print(sites[:5])
# Out:
# ['https://www.realestate.co.nz/3745538/residential/rent/20-9a-esplanade-road-mount-eden', 'https://www.realestate.co.nz/42187622/residential/rent/46-montrose-street-point-chevalier', 'https://www.realestate.co.nz/42193564/residential/rent/1-351-mount-eden-road-mount-eden', 'https://www.realestate.co.nz/42195889/residential/rent/64-school-road-kingsland', 'https://www.realestate.co.nz/42202198/residential/rent/2e-25-rutland-street-auckland-central']

# %%
sites = [url for url in sites if not url.endswith('rent')]
sites.remove('Extracted 10 links from page 20')

# %%
siteurls = sites[:]

# %%
quantity_elements = len(sites)
print("Elements:", quantity_elements)
# Out:
# Elements: 389

# %% [markdown]
# After collecting the links and evaluating their quality, we removed any potentially unreliable links. We ended up with 389 valid elements to be visited.

# %% [markdown]
# -----------------------------------------------------------

# %% [markdown]
# ## 2 step
#
# The following algorithm is a web scraper that utilizes Selenium, an automation tool, to navigate and fetch data from specific websites. Its primary purpose is to extract information about properties, such as addresses and prices, from provided URLs and store this data neatly into a structured format.
#
# To maximize efficiency and speed, the script breaks down the list of websites into chunks and processes them simultaneously, using a technique called multithreading. This is akin to deploying multiple virtual browsers all working together. If the program encounters issues while scraping a site, it's designed to retry a couple of times before logging an error and proceeding to the next site.
#
# After all the property information is compiled, the script saves everything into a CSV file for easy viewing and further analysis. This ensures that even large amounts of data are preserved and presented in a user-friendly manner.

# %%
import threading
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, TimeoutException
import pandas as pd

MAX_RETRIES = 2

def initialize_driver():
    options = webdriver.ChromeOptions()
    prefs = {
        "profile.managed_default_content_settings.images": 2,
        "profile.default_content_setting_values.notifications": 2,
        "profile.default_content_setting_values.popups": 2
    }
    options.add_experimental_option("prefs", prefs)
    driver = webdriver.Chrome(options=options)
    driver.maximize_window()
    return driver

def extract_info_chunk(start_idx, end_idx, driver, info_chunk_list):
    for i in range(start_idx, end_idx):
        url = sites[i]
        info_dict = extract_info((url, driver))
        info_chunk_list.append(info_dict)
        print(info_dict)  

def extract_info(args):
    url, driver = args
    info_dict = {}
    
    retries = 0
    while retries < MAX_RETRIES:
        try:
            driver.get(url)
            print(f"Scraping: {url}")

            address_element = driver.find_element(By.CSS_SELECTOR, "h1[data-test='listing-title']")
            address = address_element.text.strip()
            info_dict["Address"] = address

            price_element = driver.find_element(By.CSS_SELECTOR, "h3.text-xl.font-semibold")
            price = price_element.text.strip()
            info_dict["Price"] = price

            elements = driver.find_elements(By.CSS_SELECTOR, "span.leading-\\[-1\\]")
            max_elements_to_extract = 8
            for i, element in enumerate(elements, start=1):
                if i > max_elements_to_extract:
                    break
                text = element.text.strip()
                info_dict[f"Info_{i}"] = text

            if len(info_dict) >= 6:
                break

        except (NoSuchElementException, TimeoutException) as e:
            retries += 1
            if retries == MAX_RETRIES:
                info_dict["Error"] = str(e)
                break

    return info_dict

if __name__ == "__main__":
   
    drivers = [initialize_driver() for _ in range(3)]
   
    info_list1 = []
    info_list2 = []
    info_list3 = []

    third_length = len(siteurls) // 3

    t1 = threading.Thread(target=extract_info_chunk, args=(0, third_length, drivers[0], info_list1))
    t2 = threading.Thread(target=extract_info_chunk, args=(third_length, 2 * third_length, drivers[1], info_list2))
    t3 = threading.Thread(target=extract_info_chunk, args=(2 * third_length, len(sites), drivers[2], info_list3))

    # iniciating threads
    t1.start()
    t2.start()
    t3.start()

    t1.join()
    t2.join()
    t3.join()

    # joinning results
    info_list = info_list1 + info_list2 + info_list3

    # closing drivers
    for driver in drivers:
        driver.quit()

    df = pd.DataFrame(info_list)
    df.to_csv('scraped_data.csv', index=False)
    print("\nScraping results:")
    print(df)

# %% [markdown]
# "The script ran smoothly; however, it took about 15 hours to process all 389 links."

# %%
import re

url = "https://raw.githubusercontent.com/robertoaltran/Population/main/scraped_data.csv"
df = pd.read_csv(url)
df = df.dropna(subset=['Address'])
temp_filename = 'temp.csv'
df.to_csv(temp_filename, index=False)
with open(temp_filename, 'r') as file:
    content = file.read()
corrected_content = re.sub(r'\n(?=[^"])', ' ', content)
corrected_temp_filename = 'corrected_temp.csv'
with open(corrected_temp_filename, 'w') as file:
    file.write(corrected_content)
df_corrected = pd.read_csv(corrected_temp_filename)

# %%
df = df_corrected

# %%
def is_numeric(value):
    #Check if the value is numeric.
    if pd.isna(value):
        return False
    try:
        int(value)
        return True
    except ValueError:
        return False

# %%
column_rename = {
    'Info_1': 'House Type',
    'Info_2': 'Bedroom',
    'Info_3': 'Bathroom',
    'Info_4': 'Garage',
    'Info_5': 'Other Feature 1',
    'Info_6': 'Other Feature 2',
}

df.rename(columns=column_rename, inplace=True)
df.drop(['Info_7', 'Info_8', 'Error'], axis=1, inplace=True)

# %%
# Convert 'Price' column to numerical by removing unwanted strings
df['Price'] = df['Price'].astype(str)

df['Price'] = df['Price'].str.replace(r'\$', '', regex=True)
df['Price'] = df['Price'].str.replace(r' per week', '', regex=True)
df['Price'] = df['Price'].str.replace(r',', '', regex=True)
#df['Price'] = pd.to_numeric(df['Price'], errors='coerce')  # Convert to numeric (float)

# Handle numeric values in 'Bedroom', 'Bathroom' and 'Garage'
df['Bedroom'] = df['Bedroom'].apply(lambda x: int(x) if is_numeric(x) else None)
df['Bathroom'] = df['Bathroom'].apply(lambda x: int(x) if is_numeric(x) else None)
mask_non_numeric_garage = ~df['Garage'].apply(is_numeric)
df.loc[mask_non_numeric_garage, ['Garage', 'Other Feature 1', 'Other Feature 2']] = df.loc[mask_non_numeric_garage, ['Other Feature 1', 'Garage', 'Other Feature 2']].values

# Convert the columns to Int64 type
for col in ['Bedroom', 'Bathroom', 'Garage']:
    df[col] = pd.to_numeric(df[col], errors='coerce').astype(pd.Int64Dtype())

# Handle cases where 'Other Feature 2' is numeric but 'Other Feature 1' isn't
mask = df['Other Feature 2'].apply(is_numeric) & ~df['Other Feature 1'].apply(is_numeric)
df.loc[mask, ['Other Feature 1', 'Other Feature 2']] = df.loc[mask, ['Other Feature 2', 'Other Feature 1']].values

# Add up numeric 'Garage' and 'Other Feature 1' values
mask = df['Garage'].apply(is_numeric) & df['Other Feature 1'].apply(is_numeric)
df.loc[mask, 'Garage'] += df.loc[mask, 'Other Feature 1'].astype(int)
df.loc[mask, 'Other Feature 1'] = df.loc[mask, 'Other Feature 2']
df.loc[mask, 'Other Feature 2'] = None

# Handle 'Furniture'
df['Furniture'] = 0
furnished_mask = df['Other Feature 1'].str.contains('Furnished', na=False) | df['Other Feature 2'].str.contains('Furnished', na=False)
df.loc[furnished_mask, 'Furniture'] = 1
df.loc[furnished_mask, ['Other Feature 1', 'Other Feature 2']] = None

non_furnished_mask = df['Other Feature 1'].str.contains('Non furnished', na=False) | df['Other Feature 2'].str.contains('Non furnished', na=False)
df.loc[non_furnished_mask, ['Other Feature 1', 'Other Feature 2']] = None

# Impute missing values in 'House Type'
df['House Type'].fillna('Unknown', inplace=True)

# One-hot encoding for 'House Type'
df = pd.get_dummies(df, columns=['House Type'], prefix='Type')

# Ensure all categories are present and if not, add them
categories = ["House", "Apartment", "Unit", "Townhouse", "Unknown"]
for cat in categories:
    col_name = 'Type_' + cat
    if col_name not in df.columns:
        df[col_name] = 0

# %%
df.head()
# Out:
#                                              Address Price  Bedroom  Bathroom  \
# 0    20/9A Esplanade Road, Mount Eden, Auckland City   360        1         1
# 1  46 Montrose Street, Point Chevalier, Auckland ...   650        2         1
# 2   1/351 Mount Eden Road, Mount Eden, Auckland City   530        2         1
# 3           64 School Road, Kingsland, Auckland City   750        3         1
# 4  2E/25 Rutland Street, Auckland Central, Auckla...   370        1         1
#
#    Garage Other Feature 1 Other Feature 2  Furniture  Type_Apartment  \
# 0       1             NaN             NaN          0               0
# 1       2             NaN             NaN          0               0
# 2    <NA>             NaN             NaN          0               0
# 3       2             NaN             NaN          0               0
# 4    <NA>            None            None          0               1
#
#    Type_Carpark  Type_House  Type_Studio  Type_Townhouse  Type_Unit  \
# 0             0           0            0               0          1
# 1             0           1            0               0          0
# 2             0           1            0               0          0
# 3             0           1            0               0          0
# 4             0           0            0               0          0
#
#    Type_Unknown
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
df['Suburb'] = df['Address'].str.split(',').str[-2].str.strip()

# %%
df.head()
# Out:
#                                              Address Price  Bedroom  Bathroom  \
# 0    20/9A Esplanade Road, Mount Eden, Auckland City   360        1         1
# 1  46 Montrose Street, Point Chevalier, Auckland ...   650        2         1
# 2   1/351 Mount Eden Road, Mount Eden, Auckland City   530        2         1
# 3           64 School Road, Kingsland, Auckland City   750        3         1
# 4  2E/25 Rutland Street, Auckland Central, Auckla...   370        1         1
#
#    Garage Other Feature 1 Other Feature 2  Furniture  Type_Apartment  \
# 0       1             NaN             NaN          0               0
# 1       2             NaN             NaN          0               0
# 2    <NA>             NaN             NaN          0               0
# 3       2             NaN             NaN          0               0
# 4    <NA>            None            None          0               1
#
#    Type_Carpark  Type_House  Type_Studio  Type_Townhouse  Type_Unit  \
# 0             0           0            0               0          1
# 1             0           1            0               0          0
# 2             0           1            0               0          0
# 3             0           1            0               0          0
# 4             0           0            0               0          0
#
#    Type_Unknown            Suburb
# 0             0        Mount Eden
# 1             0   Point Chevalier
# 2             0        Mount Eden
# 3             0         Kingsland
# 4             0  Auckland Central

# %%
unique_values = df['Suburb'].unique()
string_values = [value for value in unique_values if isinstance(value, str)]
sorted_unique_values = sorted(string_values)

for value in sorted_unique_values:
    print(value)
# Out:
# Auckland Central
# Avondale
# Blockhouse Bay
# Eden Terrace
# Ellerslie
# Epsom
# Freemans Bay
# Glen Innes
# Glendowie
# Grafton
# Greenlane
# Grey Lynn
# Herne Bay
# Hillsborough
# Kingsland
# Kohimarama
# Meadowbank
# Mission Bay
# Morningside
# Mount Albert
# Mount Eden
# Mount Roskill
# Mount Wellington
# New Windsor
# Newmarket
# One Tree Hill
# Onehunga
# Otahuhu
# Parnell
# Point Chevalier
# Point England
# Ponsonby
# Remuera
# Royal Oak
# Saint Heliers
# Saint Johns
# Saint Marys Bay
# Sandringham
# St Heliers
# Stonefields
# Three Kings
# Waiotaiki Bay
# Waterview
# Westmere

# %%
df.to_csv('RealstateRent.csv', index=False)

# %%
dfinal = df

# %% [markdown]
# This program is made to fix and organize data about properties from an online file.
#
# First, the program gets data from a website link and removes any entries without an address. It saves this data to a file, checks for any mistakes like extra lines, and then corrects them. After making these fixes, it reads the data back and gets ready for more detailed changes.
#
# The main job of the program is to make the property data easy to understand. It gives new names to some columns to make them clearer. It removes unnecessary information and changes the price details to simple numbers by getting rid of symbols and words. The program also checks details like the number of rooms and parking spaces, making sure they are in the right place and shown as numbers. It also looks for houses that come with or without furniture, marking them correctly. At the end, it changes the property type (like "House" or "Apartment") into a format that a computer can easily understand. If any type is missing, the program adds it. Now, the cleaned-up data is ready for more use, like studying or making predictions.

# %% [markdown]
# ----------------------------------------------------------------

# %% [markdown]
# ## 3 step
#
# Gathering good data is very important for study. For this project, data was looked into different areas using the police website and nz.statistics. And it was mainly used the 2018 census for information. Even though it was from 2018, it was updated in 2020, so it's still recent.

# %%
pd.set_option('display.max_columns', None)

# %%
# !pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (1.3.4)
# Requirement already satisfied: openpyxl in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from pandas) (1.20.3)
# Requirement already satisfied: et-xmlfile in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in /Users/robertoaltran/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)

# %%
url = 'https://raw.githubusercontent.com/robertoaltran/Population/main/2018-SA1-dataset-household-AucklandRegion.csv'
data2 = pd.read_csv(url)

# %%
data2 = data2.iloc[:, [0, 1, 4]]
headers = data2.iloc[0]
data2 = data2[1:]
data2.columns = headers
data2.head()
# Out:
# 0 Area_Code              Area_Description  2018.0
# 1    110200           Okahukura Peninsula   522.0
# 2    110300   Inlet Kaipara Harbour South     0.0
# 3    110400                   Cape Rodney  1275.0
# 4    110500                     Wellsford   654.0
# 5    110600  Oceanic Auckland Region East     6.0

# %% [markdown]
# ### Total households:
#
# This metric shows the number of homes currently being lived in. It can help gauge housing demand in an area.

# %% [markdown]
# -----------------

# %%
url = 'https://raw.githubusercontent.com/robertoaltran/Population/main/2018-SA1-dataset-individual-part-1-AucklandRegion_updated_28-7-20.csv'
data3 = pd.read_csv(url)

# %%
data3 = data3.iloc[:, [0, 1, 4] + list(range(61, 78)) + [80] + list(range(91, 94)) + list(range(346, 353))]

# %%
headers = data3.iloc[0]
data3 = data3[1:]
data3.columns = headers
data3.head()
# Out:
# 0 Area_Code              Area_Description 2018 Census  0-4 years 5-9 years  \
# 1    110200           Okahukura Peninsula        1491         99        96
# 2    110300   Inlet Kaipara Harbour South           0          C         C
# 3    110400                   Cape Rodney        3525        216       234
# 4    110500                     Wellsford        1929        168       150
# 5    110600  Oceanic Auckland Region East           9          C         C
#
# 0 10-14 years 15-19 years 20-24 years 25-29 years 30-34 years 35-39 years  \
# 1         111          84          75          72          78          93
# 2           C           C           C           C           C           C
# 3         237         168         153         168         177         201
# 4         129         138         105         138         150         123
# 5           C           C           C           C           C           C
#
# 0 40-44 years 45-49 years 50-54 years 55-59 years 60-64 years 65-69 years  \
# 1          87          99         105         162         105          84
# 2           C           C           C           C           C           C
# 3         204         240         264         312         291         258
# 4         105          93         114         108          84          99
# 5           C           C           C           C           C           C
#
# 0 70-74 years 75-79 years 80-84 years Median age(17)  Under 15 years  \
# 1          51          48          21           41.7             306
# 2           C           C           C              C               C
# 3         198         123          51             45             687
# 4          87          57          42           34.4             447
# 5           C           C           C             62               0
#
# 0 15-29 years 30-64 years Less than one year 1 year 2 years 3 years 4 years  \
# 1         234         732                  6      3       3       9       3
# 2           C           C                  C      C       C       C       C
# 3         489        1683                 27     21      21      18      21
# 4         384         777                 12     18       6      18       6
# 5           0           6                  C      C       C       C       C
#
# 0 5-9 years 10-19 years
# 1        33          60
# 2         C           C
# 3        66         138
# 4        78          78
# 5         C           C

# %% [markdown]
# **Census usually resident population count**:
#   The total number of people who live in an area most of the time.
#
# **Age in five year groups**:
#  Grouping people by age, like 0-5 years, 6-10 years, and so on.
#
# **Age in broad groups**:
#  Grouping people by age in larger groups, like children, adults, and seniors.
#
# **Years at usual residence**:
#  How many years a person has lived in their current home.
#
# updated_28-7-20

# %% [markdown]
# ----------------

# %%
url = 'https://raw.githubusercontent.com/robertoaltran/Population/main/2018-SA1-dataset-individual-part-2-AucklandRegion.csv'
data4 = pd.read_csv(url)

# %%
data4 = data4.iloc[:, [0, 1] + list(range(174, 180)) + list(range(215, 226)) + list(range(264, 270))+ [274]]

# %%
headers = data4.iloc[0]
data4 = data4[1:]
data4.columns = headers

data4.head()
# Out:
# 0 Area_Code              Area_Description No children One child Two children  \
# 1    110200           Okahukura Peninsula         108        93          141
# 2    110300   Inlet Kaipara Harbour South           C         C            C
# 3    110400                   Cape Rodney         315       156          378
# 4    110500                     Wellsford         150        87          159
# 5    110600  Oceanic Auckland Region East           C         C            C
#
# 0 Three children Four children Five children No qualification  \
# 1             90            48            21              225
# 2              C             C             C                C
# 3            246           120            33              495
# 4            144            75            33              381
# 5              C             C             C                C
#
# 0 Level 1 certificate Level 2 certificate Level 3 certificate  \
# 1                 198                 156                 135
# 2                   C                   C                   C
# 3                 357                 321                 249
# 4                 219                 186                 141
# 5                   C                   C                   C
#
# 0 Level 4 certificate Level 5 diploma Level 6 diploma  \
# 1                 120              54              45
# 2                   C               C               C
# 3                 315             129             150
# 4                 132              57              48
# 5                   C               C               C
#
# 0 Bachelor degree and Level 7 qualification Post-graduate and honours degrees  \
# 1                                        93                                30
# 2                                         C                                 C
# 3                                       333                               102
# 4                                        90                                30
# 5                                         C                                 C
#
# 0 Masters degree Doctorate degree $5,000 or less $5,001 – $10,000  \
# 1             15                3            132               57
# 2              C                C              C                C
# 3             81               39            312              123
# 4             15                0            192               72
# 5              C                C              C                C
#
# 0 $10,001 – $20,000 $20,001 – $30,000 $30,001 – $50,000 $50,001 – $70,000  \
# 1               198               168               288               177
# 2                 C                 C                 C                 C
# 3               504               408               642               393
# 4               321               270               303               195
# 5                 C                 C                 C                 C
#
# 0 Median personal income($)
# 1                     32600
# 2                         C
# 3                     32100
# 4                     25400
# 5                     12600

# %% [markdown]
# ### Feature Relevance for House Rental Price Model:
#
# When predicting house rental prices in New Zealand, it's essential to determine the relevance of potential features. Below is a brief overview:
#
#
# **Number of Children Born**: Can influence demand for property type and size.
#
# **Education Metrics**: Locations near educational institutions or with a high student population might have specific rental demands.
#
# **Income Metrics**: Areas with higher incomes might exhibit higher rental prices. The source of income can offer additional insights.
#
# **Travel Means to Education**: Indicates transport infrastructure and proximity to educational establishments.

# %% [markdown]
# -------------------------------

# %%
url = 'https://raw.githubusercontent.com/robertoaltran/Population/main/2018-SA1-dataset-individual-part-3a-AucklandRegion.csv'
data5 = pd.read_csv(url)

# %%
data5 = data5.iloc[:, [0, 1] + list(range(16, 21)) + list(range(66, 73)) + list(range(156, 172))]

# %%
headers = data5.iloc[0]
data5 = data5[1:]
data5.columns = headers
data5.head()
# Out:
# 0 Area_Code              Area_Description Employed Full time  \
# 1    110200           Okahukura Peninsula                639
# 2    110300   Inlet Kaipara Harbour South                  C
# 3    110400                   Cape Rodney               1329
# 4    110500                     Wellsford                681
# 5    110600  Oceanic Auckland Region East                  C
#
# 0 Employed Part time Unemployed Not in the Labour Force Total stated Managers  \
# 1                198         39                     306         1182      204
# 2                  C          C                       C            C        C
# 3                558         48                     903         2838      507
# 4                213         66                     525         1485      156
# 5                  C          C                       6            9        C
#
# 0 Professionals Technicians and Trades Workers  \
# 1            93                            117
# 2             C                              C
# 3           309                            246
# 4            96                            144
# 5             C                              C
#
# 0 Community and Personal Service Workers Clerical and Administrative Workers  \
# 1                                     75                                  66
# 2                                      C                                   C
# 3                                    147                                 186
# 4                                     78                                  87
# 5                                      C                                   C
#
# 0 Sales Workers Machinery Operators and Drivers Manufacturing  \
# 1            66                              81            72
# 2             C                               C             C
# 3           147                              93           165
# 4           117                              81            90
# 5             C                               C             C
#
# 0 Electricity Gas Water and Waste Services Construction Wholesale Trade  \
# 1                                        3          114              42
# 2                                        C            C               C
# 3                                        6          264              90
# 4                                        3          153              45
# 5                                        C            C               C
#
# 0 Retail Trade Accommodation and Food Services  \
# 1           57                              39
# 2            C                               C
# 3          126                             111
# 4          114                              78
# 5            C                               C
#
# 0 Transport Postal and Warehousing Information Media and Telecommunications  \
# 1                               42                                        6
# 2                                C                                        C
# 3                               60                                       27
# 4                               54                                        3
# 5                                C                                        C
#
# 0 Financial and Insurance Services Rental Hiring and Real Estate Services  \
# 1                               12                                     15
# 2                                C                                      C
# 3                               21                                     51
# 4                               15                                      6
# 5                                C                                      C
#
# 0 Professional Scientific and Technical Services  \
# 1                                             42
# 2                                              C
# 3                                            156
# 4                                             63
# 5                                              C
#
# 0 Administrative and Support Services Public Administration and Safety  \
# 1                                  39                               24
# 2                                   C                                C
# 3                                  72                               24
# 4                                  33                               15
# 5                                   C                                C
#
# 0 Education and Training Health Care and Social Assistance  \
# 1                     48                                54
# 2                      C                                 C
# 3                    141                               135
# 4                     54                                54
# 5                      C                                 C
#
# 0 Arts and Recreation Services
# 1                            9
# 2                            C
# 3                           57
# 4                           12
# 5                            C

# %% [markdown]
# **Work and Labour Force Status**:
# - This shows how many people in an area have jobs. Places with more people working might have higher rent prices because more people need homes.
#
# **Status in Employment**:
# - This tells us what kind of jobs people have, like full-time or part-time. Areas with many full-time workers might have higher rents because they have a steady income.
#
# **Occupation by Residence & Workplace Address**:
# - This information reveals the types of jobs people do and where they work. Areas with lots of high-paying jobs, like doctors or lawyers, might have higher rents. Also, if people live close to their work, they might be willing to pay more for rent.
#
# **Industry by Residence & Workplace Address**:
# - This tells us about the businesses and industries where people work. For instance, areas close to big business hubs might have higher rents. On the other hand, places with seasonal jobs might have different rent patterns.

# %% [markdown]
# -------------------------

# %%
url = 'https://raw.githubusercontent.com/robertoaltran/Population/main/2018-SA1-dataset-individual-part-3b-AucklandRegion_updated_16-7-20.csv'
data6 = pd.read_csv(url, header = 1)

# %%
data6 = data6.iloc[:, [0, 1, 32 , 38, 41, 44, 50, 53, 56]]

# %%
data6.drop(0, inplace=True)
data6.reset_index(drop=True, inplace=True)
data6.rename(columns={'Unnamed: 0': 'Area_Code', 'Unnamed: 1': 'Area_Description'}, inplace=True)

# %%
data6.head()
# Out:
#   Area_Code              Area_Description Work at home  \
# 0    110200           Okahukura Peninsula          168
# 1    110300   Inlet Kaipara Harbour South            C
# 2    110400                   Cape Rodney          375
# 3    110500                     Wellsford           57
# 4    110600  Oceanic Auckland Region East            C
#
#   Drive a private car, truck or van Drive a company car, truck or van  \
# 0                               315                                78
# 1                                 C                                 C
# 2                               564                               129
# 3                               315                               108
# 4                                 C                                 C
#
#   Passenger in a car, truck, van or company bus Train Bicycle Walk or jog
# 0                                            12     0       0          18
# 1                                             C     C       C           C
# 2                                            39     3       6          33
# 3                                            39     0       3          81
# 4                                             C     C       C           C

# %% [markdown]
# **Main Means of Travel to Work by Residence & Workplace Address**:
# - This shows how people get to their jobs, like by car, bus, or walking. Areas with good public transport might have higher rents because it's easier for people to get around. On the other hand, places where most people drive might need homes with parking spaces.

# %% [markdown]
# ------------------------------------------

# %%
url = 'https://raw.githubusercontent.com/robertoaltran/Population/main/ANZSOC_Full%20Data_data-auckland.csv'  
data8 = pd.read_csv(url)
data8.head()
# Out:
#                                      ANZSOC Division Year Month  \
# 0  Abduction, Harassment and Other Related Offenc...     Dec-22
# 1  Abduction, Harassment and Other Related Offenc...     Oct-22
# 2  Abduction, Harassment and Other Related Offenc...     Dec-22
# 3  Abduction, Harassment and Other Related Offenc...     Dec-22
# 4  Abduction, Harassment and Other Related Offenc...     Oct-22
#
#    Victimisations       Area Unit  Number of Records Territorial Authority
# 0               1  Mangere South.                  1             Auckland.
# 1               1      Royal Oak.                  1             Auckland.
# 2               1         Mascot.                  1             Auckland.
# 3               1       Balmoral.                  1             Auckland.
# 4               1          Drury.                  1             Auckland.

# %%
data8['Area Unit'] = data8['Area Unit'].str.replace(r'\.$', '', regex=True)

# %% [markdown]
# ## Auckland - Crime Categories and Incidents:
#
# **Acts Intended to Cause Injury**
# This category involves deliberate acts where the intent was to inflict harm or injury to another individual.
#
# **Sexual Assault and Related Offences**
# These are offenses that involve any unwanted sexual activity or behavior without the explicit consent of the victim.
#
# **Abduction, Harassment and Other Related Offences Against Personal Liberty**
# This category encompasses crimes where a person's freedom or liberty is violated, including kidnapping and harassment.
#
# **Robbery, Extortion and Related Offences**
# Such crimes involve forcibly taking something of value from another person, often coupled with threats or violence.
#
# **Unlawful Entry With Intent/Burglary, Break and Enter**
# These are offenses where individuals unlawfully enter property, usually with the intent to commit theft or another crime.
#
# **Theft and Related Offences**
# This category covers various forms of theft, from petty thefts to more significant robberies, excluding break-ins.
#
#
# ### Source of Data:
# The data is derived from the "Victimisation Time and Place" dataset, which offers detailed insights into when and where crimes occurred across Auckland.

# %% [markdown]
# ------------------------------

# %% [markdown]
# ## Data Cleaning
#
# With the gathered data on the properties and their respective neighborhoods, a crucial next step is data cleaning and preprocessing. Ensuring that data is accurate and in a usable format is important to the success of any machine learning model. We have done on a comprehensive process to structure the data effectively. This involves combining information from different sources, making it cohesive and consistent. Cleaning techniques such as using pivot tables played and corrected instances of duplicate names and undertook reformatting measures. These steps ensure that the data is not only accurate but optimized for the model, making it better for efficient analysis.

# %%
data_crimes_2023 = data8[data8['Year Month'].str.contains('23')]
grouped_crimes = data_crimes_2023.groupby(['Area Unit', 'ANZSOC Division'])['Victimisations'].sum().reset_index()
pivot_crimes = grouped_crimes.pivot_table(index='Area Unit', columns='ANZSOC Division', values='Victimisations', fill_value=0).reset_index()

# %%
pivot_crimes.head()
# Out:
# ANZSOC Division     Area Unit  \
# 0                         -29
# 1                      999999
# 2                Abbotts Park
# 3                     Akarana
# 4                      Albany
#
# ANZSOC Division  Abduction, Harassment and Other Related Offences Against a Person  \
# 0                                                                0
# 1                                                                1
# 2                                                                0
# 3                                                                0
# 4                                                                1
#
# ANZSOC Division  Acts Intended to Cause Injury  \
# 0                                            2
# 1                                           66
# 2                                            8
# 3                                           20
# 4                                           80
#
# ANZSOC Division  Robbery, Extortion and Related Offences  \
# 0                                                      0
# 1                                                     16
# 2                                                      4
# 3                                                      2
# 4                                                     15
#
# ANZSOC Division  Sexual Assault and Related Offences  \
# 0                                                  0
# 1                                                 28
# 2                                                  1
# 3                                                  1
# 4                                                  4
#
# ANZSOC Division  Theft and Related Offences  \
# 0                                         7
# 1                                       204
# 2                                       197
# 3                                        96
# 4                                       734
#
# ANZSOC Division  Unlawful Entry With Intent/Burglary, Break and Enter
# 0                                                                1
# 1                                                               28
# 2                                                               50
# 3                                                               73
# 4                                                               63

# %%
unique_value = pivot_crimes['Area Unit'].unique()
string_values = [value for value in unique_value if isinstance(value, str)]
sorted_unique_value = sorted(string_values)

# %%
pivot_crimes['Area Unit'] = pivot_crimes['Area Unit'].str.replace(r' (North|South|East|West|Central)\b', '', regex=True)
pivot_crimes['Area Unit'] = pivot_crimes['Area Unit'].str.replace(r' \(Auckland\)', '', regex=True)

# %%
result = pivot_crimes.groupby('Area Unit').sum().reset_index()

# %%
result['Area Unit'] = result['Area Unit'].replace(['Auckland City-Marinas', 'Auckland Harbourside'], 'Auckland')

# %%
dataframes = [data2, data3, data4, data5, data6]
names = ['data2', 'data3', 'data4', 'data5', 'data6']

for df, name in zip(dataframes, names):
    if 'Area_Description' not in df.columns:
        print(f"{name} doesn't have 'Area_Description' column.")

# %%
merged_df = data2.merge(data3, on=['Area_Code', 'Area_Description'], how='outer')
merged_df = merged_df.merge(data4, on=['Area_Code', 'Area_Description'], how='outer')
merged_df = merged_df.merge(data5, on=['Area_Code', 'Area_Description'], how='outer')
merged_df = merged_df.merge(data6, on=['Area_Code', 'Area_Description'], how='outer')

# %%
merged_final = merged_df

# %%
unique_values = merged_df['Area_Description'].unique()
string_values = [value for value in unique_values if isinstance(value, str)]
sorted_unique_values = sorted(string_values)

# %%
merged_final['Area_Description'] = merged_final['Area_Description'].str.replace(r' (North|South|East|West|Central)\b', '', regex=True)
merged_final['Area_Description'] = merged_final['Area_Description'].str.replace(r' \(Auckland\)', '', regex=True)

# %%
object_cols = merged_final.select_dtypes(include=['object']).columns
for col in object_cols:
    try:
        _ = pd.to_numeric(merged_final[col], errors='coerce')
    except Exception as e:
        print(f"Error in column {col}: {e}")
# Out:
# Error in column 5-9 years: arg must be a list, tuple, 1-d array, or Series
# Error in column 5-9 years: arg must be a list, tuple, 1-d array, or Series

# %%
cols = merged_final.columns.tolist()
index_of_duplicate = cols.index("5-9 years")
cols[index_of_duplicate] = "5-9 year"
merged_final.columns = cols

# %%
import numpy as np
object_cols_list = object_cols.tolist()

if 'Area_Description' in object_cols_list:
    object_cols_list.remove('Area_Description')

for col in object_cols_list:
    merged_final[col] = merged_final[col].replace('C', np.nan)
    merged_final[col] = pd.to_numeric(merged_final[col], errors='coerce')

# %%
merged_final = merged_final.sort_values(by='Area_Description')

merged_final.head()
# Out:
#      Area_Code Area_Description  2018.0  2018 Census   0-4 years 5-9 year  \
# 170   127200.0         Akoranga   405.0       1167.0        42.0       39
# 71    117300.0           Albany   162.0        525.0        18.0       12
# 72    117400.0           Albany   882.0       2811.0       126.0      189
# 79    118100.0           Albany  1143.0       3405.0       171.0      186
# 65    116700.0   Albany Heights  1053.0       3153.0       210.0      192
#
#      10-14 years  15-19 years  20-24 years  25-29 years  30-34 years  \
# 170         27.0        153.0        105.0         84.0         57.0
# 71           6.0         93.0         96.0         54.0         57.0
# 72         171.0        183.0        234.0        156.0        162.0
# 79         198.0        222.0        306.0        231.0        243.0
# 65         165.0        189.0        375.0        300.0        312.0
#
#      35-39 years  40-44 years  45-49 years  50-54 years  55-59 years  \
# 170         45.0         33.0         48.0         39.0         36.0
# 71          30.0         36.0         30.0         18.0         18.0
# 72         204.0        171.0        180.0        159.0        144.0
# 79         237.0        219.0        264.0        234.0        189.0
# 65         288.0        195.0        186.0        201.0        186.0
#
#      60-64 years  65-69 years  70-74 years  75-79 years  80-84 years  \
# 170         39.0         33.0         48.0         69.0         87.0
# 71          21.0         15.0          6.0          3.0          3.0
# 72          93.0         90.0        138.0        144.0        117.0
# 79         195.0        168.0        114.0         81.0         51.0
# 65         153.0         93.0         45.0         33.0         18.0
#
#      Median age(17)   Under 15 years  15-29 years  30-64 years  \
# 170            43.9            108.0        342.0        291.0
# 71             28.4             39.0        246.0        213.0
# 72             39.6            483.0        570.0       1104.0
# 79             38.0            555.0        756.0       1578.0
# 65             32.4            567.0        864.0       1521.0
#
#      Less than one year  1 year  2 years  3 years  4 years  5-9 years  \
# 170                21.0    18.0     18.0     18.0     12.0       48.0
# 71                 45.0    24.0     30.0     18.0      9.0       51.0
# 72                141.0   159.0    108.0     72.0     60.0      204.0
# 79                132.0   150.0    117.0     66.0     69.0      312.0
# 65                132.0   177.0    114.0    120.0    102.0      393.0
#
#      10-19 years  No children  One child  Two children  Three children  \
# 170        126.0        237.0       66.0         111.0            87.0
# 71          72.0        156.0       24.0          30.0             9.0
# 72         447.0        318.0      165.0         384.0           177.0
# 79         645.0        465.0      234.0         438.0           174.0
# 65         576.0        486.0      234.0         312.0           117.0
#
#      Four children  Five children  No qualification  Level 1 certificate  \
# 170           36.0           24.0             147.0                 87.0
# 71             3.0            3.0              24.0                 21.0
# 72            54.0           30.0             306.0                204.0
# 79            42.0           15.0             258.0                201.0
# 65            30.0            6.0             150.0                147.0
#
#      Level 2 certificate  Level 3 certificate  Level 4 certificate  \
# 170                 78.0                195.0                 51.0
# 71                  27.0                126.0                 27.0
# 72                 159.0                216.0                123.0
# 79                 195.0                324.0                171.0
# 65                 150.0                303.0                120.0
#
#      Level 5 diploma  Level 6 diploma  \
# 170             36.0             75.0
# 71               9.0             12.0
# 72              93.0            117.0
# 79             129.0            123.0
# 65             114.0            123.0
#
#      Bachelor degree and Level 7 qualification  \
# 170                                      132.0
# 71                                        90.0
# 72                                       387.0
# 79                                       537.0
# 65                                       585.0
#
#      Post-graduate and honours degrees  Masters degree  Doctorate degree  \
# 170                               45.0            36.0               6.0
# 71                                21.0            27.0               3.0
# 72                               126.0           135.0              21.0
# 79                               180.0           192.0              30.0
# 65                               183.0           174.0              15.0
#
#      $5,000 or less  $5,001 – $10,000  $10,001 – $20,000  $20,001 – $30,000  \
# 170           168.0              78.0              201.0              267.0
# 71            144.0              33.0               90.0               39.0
# 72            465.0             117.0              345.0              333.0
# 79            534.0             153.0              381.0              354.0
# 65            507.0             132.0              291.0              225.0
#
#      $30,001 – $50,000  $50,001 – $70,000  Median personal income($)  \
# 170              192.0               81.0                    22100.0
# 71                78.0               54.0                    17400.0
# 72               420.0              249.0                    26100.0
# 79               531.0              375.0                    30300.0
# 65               480.0              363.0                    36700.0
#
#      Employed Full time  Employed Part time  Unemployed  \
# 170               285.0               129.0        51.0
# 71                201.0                90.0        30.0
# 72                852.0               324.0        72.0
# 79               1317.0               399.0        99.0
# 65               1371.0               390.0       111.0
#
#      Not in the Labour Force  Total stated  Managers  Professionals  \
# 170                    591.0        1056.0      48.0           96.0
# 71                     171.0         489.0      45.0           84.0
# 72                    1080.0        2325.0     240.0          300.0
# 79                    1035.0        2853.0     354.0          459.0
# 65                     714.0        2586.0     402.0          495.0
#
#      Technicians and Trades Workers  Community and Personal Service Workers  \
# 170                            45.0                                    72.0
# 71                             21.0                                    36.0
# 72                            123.0                                    87.0
# 79                            165.0                                   132.0
# 65                            162.0                                   141.0
#
#      Clerical and Administrative Workers  Sales Workers  \
# 170                                 42.0           60.0
# 71                                  30.0           42.0
# 72                                 141.0          168.0
# 79                                 231.0          213.0
# 65                                 213.0          210.0
#
#      Machinery Operators and Drivers  Manufacturing  \
# 170                              9.0           21.0
# 71                              12.0           21.0
# 72                              51.0           93.0
# 79                              63.0          120.0
# 65                              54.0          111.0
#
#      Electricity Gas Water and Waste Services  Construction  Wholesale Trade  \
# 170                                       3.0          33.0             18.0
# 71                                        0.0          21.0             18.0
# 72                                        6.0         105.0            102.0
# 79                                       12.0         129.0            153.0
# 65                                        9.0         144.0            144.0
#
#      Retail Trade  Accommodation and Food Services  \
# 170          45.0                             51.0
# 71           48.0                             15.0
# 72          153.0                             84.0
# 79          183.0                            126.0
# 65          231.0                            111.0
#
#      Transport Postal and Warehousing  \
# 170                              15.0
# 71                                9.0
# 72                               30.0
# 79                               63.0
# 65                               48.0
#
#      Information Media and Telecommunications  \
# 170                                       9.0
# 71                                        9.0
# 72                                       36.0
# 79                                       36.0
# 65                                       48.0
#
#      Financial and Insurance Services  Rental Hiring and Real Estate Services  \
# 170                              12.0                                     3.0
# 71                                9.0                                     0.0
# 72                               42.0                                    39.0
# 79                               93.0                                    39.0
# 65                               99.0                                    51.0
#
#      Professional Scientific and Technical Services  \
# 170                                            51.0
# 71                                             36.0
# 72                                            159.0
# 79                                            249.0
# 65                                            285.0
#
#      Administrative and Support Services  Public Administration and Safety  \
# 170                                 24.0                              15.0
# 71                                  12.0                               9.0
# 72                                  51.0                              36.0
# 79                                  75.0                              66.0
# 65                                  87.0                              57.0
#
#      Education and Training  Health Care and Social Assistance  \
# 170                    27.0                               48.0
# 71                     36.0                               18.0
# 72                     90.0                               87.0
# 79                    150.0                              135.0
# 65                    138.0                              108.0
#
#      Arts and Recreation Services  Work at home  \
# 170                          18.0          12.0
# 71                            3.0           6.0
# 72                           15.0          78.0
# 79                           36.0          84.0
# 65                           33.0          72.0
#
#      Drive a private car, truck or van  Drive a company car, truck or van  \
# 170                              135.0                               21.0
# 71                                42.0                                3.0
# 72                               534.0                              138.0
# 79                               945.0                              240.0
# 65                               507.0                              111.0
#
#      Passenger in a car, truck, van or company bus  Train  Bicycle  \
# 170                                            9.0    0.0      3.0
# 71                                             6.0    0.0      0.0
# 72                                            36.0    3.0      6.0
# 79                                            63.0    0.0      9.0
# 65                                            33.0    0.0      3.0
#
#      Walk or jog
# 170         36.0
# 71           3.0
# 72          33.0
# 79          57.0
# 65          21.0

# %%
del merged_final['Area_Code']
merged_final['Area_Description'] = merged_final['Area_Description'].replace(['Auckland Airport', 'Auckland-University'], 'Auckland')

# %%
numerical_columns = merged_final.select_dtypes(include=[np.number]).columns
merged_final[numerical_columns] = merged_final[numerical_columns].fillna(0)

# %%
merged_final = merged_final.groupby('Area_Description').sum().reset_index()

# %%
merged_final = merged_final.merge(pivot_crimes, left_on='Area_Description', right_on='Area Unit', how='outer')

# %%
merged_final = merged_final.drop_duplicates(subset='Area_Description', keep='first')

# %%
merged_final.head()
# Out:
#             Area_Description  2018.0  2018 Census   0-4 years  10-14 years  \
# 0                   Akoranga   405.0       1167.0        42.0         27.0
# 1                     Albany  2187.0       6741.0       315.0        375.0
# 2             Albany Heights  1053.0       3153.0       210.0        165.0
# 3                  Alfriston  1059.0       3807.0       243.0        237.0
# 4  Algies Bay-Scotts Landing   498.0       1185.0        45.0         42.0
#
#    15-19 years  20-24 years  25-29 years  30-34 years  35-39 years  \
# 0        153.0        105.0         84.0         57.0         45.0
# 1        498.0        636.0        441.0        462.0        471.0
# 2        189.0        375.0        300.0        312.0        288.0
# 3        225.0        285.0        309.0        303.0        249.0
# 4         45.0         27.0         27.0         48.0         33.0
#
#    40-44 years  45-49 years  50-54 years  55-59 years  60-64 years  \
# 0         33.0         48.0         39.0         36.0         39.0
# 1        426.0        474.0        411.0        351.0        309.0
# 2        195.0        186.0        201.0        186.0        153.0
# 3        198.0        252.0        228.0        216.0        204.0
# 4         48.0         72.0         60.0         90.0        117.0
#
#    65-69 years  70-74 years  75-79 years  80-84 years  Median age(17)  \
# 0         33.0         48.0         69.0         87.0            43.9
# 1        273.0        258.0        228.0        171.0           106.0
# 2         93.0         45.0         33.0         18.0            32.4
# 3        129.0        129.0        102.0        111.0            36.0
# 4        135.0        126.0         78.0         51.0            60.2
#
#     Under 15 years  15-29 years  30-64 years  Less than one year  1 year  \
# 0            108.0        342.0        291.0                21.0    18.0
# 1           1077.0       1572.0       2895.0               318.0   333.0
# 2            567.0        864.0       1521.0               132.0   177.0
# 3            726.0        816.0       1656.0                45.0    54.0
# 4            135.0         99.0        471.0                 6.0    12.0
#
#    2 years  3 years  4 years  5-9 years  10-19 years  No children  One child  \
# 0     18.0     18.0     12.0       48.0        126.0        237.0       66.0
# 1    255.0    156.0    138.0      567.0       1164.0        939.0      423.0
# 2    114.0    120.0    102.0      393.0        576.0        486.0      234.0
# 3     60.0     51.0     48.0      294.0        699.0        408.0      219.0
# 4      6.0      9.0      9.0       33.0         48.0        111.0       45.0
#
#    Two children  Three children  Four children  Five children  \
# 0         111.0            87.0           36.0           24.0
# 1         852.0           360.0           99.0           48.0
# 2         312.0           117.0           30.0            6.0
# 3         384.0           240.0          105.0           54.0
# 4         171.0           111.0           39.0           18.0
#
#    No qualification  Level 1 certificate  Level 2 certificate  \
# 0             147.0                 87.0                 78.0
# 1             588.0                426.0                381.0
# 2             150.0                147.0                150.0
# 3             561.0                261.0                207.0
# 4             189.0                150.0                102.0
#
#    Level 3 certificate  Level 4 certificate  Level 5 diploma  Level 6 diploma  \
# 0                195.0                 51.0             36.0             75.0
# 1                666.0                321.0            231.0            252.0
# 2                303.0                120.0            114.0            123.0
# 3                297.0                204.0            144.0            138.0
# 4                 60.0                 99.0             42.0             72.0
#
#    Bachelor degree and Level 7 qualification  \
# 0                                      132.0
# 1                                     1014.0
# 2                                      585.0
# 3                                      492.0
# 4                                      138.0
#
#    Post-graduate and honours degrees  Masters degree  Doctorate degree  \
# 0                               45.0            36.0               6.0
# 1                              327.0           354.0              54.0
# 2                              183.0           174.0              15.0
# 3                              147.0            99.0              15.0
# 4                               51.0            39.0              12.0
#
#    $5,000 or less  $5,001 – $10,000  $10,001 – $20,000  $20,001 – $30,000  \
# 0           168.0              78.0              201.0              267.0
# 1          1143.0             303.0              816.0              726.0
# 2           507.0             132.0              291.0              225.0
# 3           432.0             144.0              522.0              381.0
# 4            93.0              42.0              222.0              174.0
#
#    $30,001 – $50,000  $50,001 – $70,000  Median personal income($)  \
# 0              192.0               81.0                    22100.0
# 1             1029.0              678.0                    73800.0
# 2              480.0              363.0                    36700.0
# 3              582.0              495.0                    32300.0
# 4              204.0              156.0                    29500.0
#
#    Employed Full time  Employed Part time  Unemployed  \
# 0               285.0               129.0        51.0
# 1              2370.0               813.0       201.0
# 2              1371.0               390.0       111.0
# 3              1572.0               336.0        93.0
# 4               327.0               168.0        24.0
#
#    Not in the Labour Force  Total stated  Managers  Professionals  \
# 0                    591.0        1056.0      48.0           96.0
# 1                   2286.0        5667.0     639.0          843.0
# 2                    714.0        2586.0     402.0          495.0
# 3                   1077.0        3078.0     363.0          435.0
# 4                    528.0        1050.0     108.0          126.0
#
#    Technicians and Trades Workers  Community and Personal Service Workers  \
# 0                            45.0                                    72.0
# 1                           309.0                                   255.0
# 2                           162.0                                   141.0
# 3                           201.0                                   138.0
# 4                            57.0                                    54.0
#
#    Clerical and Administrative Workers  Sales Workers  \
# 0                                 42.0           60.0
# 1                                402.0          423.0
# 2                                213.0          210.0
# 3                                252.0          234.0
# 4                                 60.0           39.0
#
#    Machinery Operators and Drivers  Manufacturing  \
# 0                              9.0           21.0
# 1                            126.0          234.0
# 2                             54.0          111.0
# 3                            147.0          258.0
# 4                             18.0           51.0
#
#    Electricity Gas Water and Waste Services  Construction  Wholesale Trade  \
# 0                                       3.0          33.0             18.0
# 1                                      18.0         255.0            273.0
# 2                                       9.0         144.0            144.0
# 3                                      12.0         171.0            147.0
# 4                                       3.0          60.0             21.0
#
#    Retail Trade  Accommodation and Food Services  \
# 0          45.0                             51.0
# 1         384.0                            225.0
# 2         231.0                            111.0
# 3         204.0                            105.0
# 4          48.0                             27.0
#
#    Transport Postal and Warehousing  Information Media and Telecommunications  \
# 0                              15.0                                       9.0
# 1                             102.0                                      81.0
# 2                              48.0                                      48.0
# 3                             159.0                                      21.0
# 4                              12.0                                      12.0
#
#    Financial and Insurance Services  Rental Hiring and Real Estate Services  \
# 0                              12.0                                     3.0
# 1                             144.0                                    78.0
# 2                              99.0                                    51.0
# 3                              54.0                                    42.0
# 4                               9.0                                    15.0
#
#    Professional Scientific and Technical Services  \
# 0                                            51.0
# 1                                           444.0
# 2                                           285.0
# 3                                           150.0
# 4                                            60.0
#
#    Administrative and Support Services  Public Administration and Safety  \
# 0                                 24.0                              15.0
# 1                                138.0                             111.0
# 2                                 87.0                              57.0
# 3                                 87.0                              69.0
# 4                                 18.0                               6.0
#
#    Education and Training  Health Care and Social Assistance  \
# 0                    27.0                               48.0
# 1                   276.0                              240.0
# 2                   138.0                              108.0
# 3                   129.0                              162.0
# 4                    42.0                               63.0
#
#    Arts and Recreation Services  Work at home  \
# 0                          18.0          12.0
# 1                          54.0         168.0
# 2                          33.0          72.0
# 3                          18.0          63.0
# 4                           6.0          72.0
#
#    Drive a private car, truck or van  Drive a company car, truck or van  \
# 0                              135.0                               21.0
# 1                             1521.0                              381.0
# 2                              507.0                              111.0
# 3                              693.0                              234.0
# 4                              195.0                               45.0
#
#    Passenger in a car, truck, van or company bus  Train  Bicycle  Walk or jog  \
# 0                                            9.0    0.0      3.0         36.0
# 1                                          105.0    3.0     15.0         93.0
# 2                                           33.0    0.0      3.0         21.0
# 3                                           39.0   21.0      0.0          9.0
# 4                                           12.0    0.0      3.0          6.0
#
#   Area Unit  \
# 0       NaN
# 1    Albany
# 2       NaN
# 3       NaN
# 4       NaN
#
#    Abduction, Harassment and Other Related Offences Against a Person  \
# 0                                                NaN
# 1                                                1.0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Acts Intended to Cause Injury  Robbery, Extortion and Related Offences  \
# 0                            NaN                                      NaN
# 1                           80.0                                     15.0
# 2                            NaN                                      NaN
# 3                            NaN                                      NaN
# 4                            NaN                                      NaN
#
#    Sexual Assault and Related Offences  Theft and Related Offences  \
# 0                                  NaN                         NaN
# 1                                  4.0                       734.0
# 2                                  NaN                         NaN
# 3                                  NaN                         NaN
# 4                                  NaN                         NaN
#
#    Unlawful Entry With Intent/Burglary, Break and Enter
# 0                                                NaN
# 1                                               63.0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
df= dfinal

# %%
cols = ['Suburb'] + [col for col in df if col != 'Suburb']
df = df[cols]
df['Suburb'] = df['Suburb'].replace('Auckland Central', 'Auckland')

# %%
df.head()
# Out:
#        Suburb                                            Address  \
# 86   Auckland  9/3 Eden Crescent, Auckland Central, Auckland ...
# 222  Auckland  2B/2 White Street, Auckland Central, Auckland ...
# 109  Auckland  406/138 Anzac Ave, Auckland Central, Auckland ...
# 110  Auckland  121/72 Nelson St , Auckland Central, Auckland ...
# 221  Auckland  72 Nelson Street, Auckland Central, Auckland City
#
#                          Price  Bedroom  Bathroom  Garage Other Feature 1  \
# 86                         620        2         1       1             NaN
# 222  Auckland Central insights        2         1    <NA>            None
# 109                        320        1         1    <NA>       1 ensuite
# 110                        470        2         1    <NA>             NaN
# 221                        375        1         1    <NA>             NaN
#
#     Other Feature 2  Furniture  Type_Apartment  Type_Carpark  Type_House  \
# 86              NaN          0               1             0           0
# 222            None          1               1             0           0
# 109             NaN          0               1             0           0
# 110             NaN          0               1             0           0
# 221             NaN          0               1             0           0
#
#      Type_Studio  Type_Townhouse  Type_Unit  Type_Unknown  2018.0  \
# 86             0               0          0             0   213.0
# 222            0               0          0             0   213.0
# 109            0               0          0             0   213.0
# 110            0               0          0             0   213.0
# 221            0               0          0             0   213.0
#
#      2018 Census   0-4 years  10-14 years  15-19 years  20-24 years  \
# 86         735.0        66.0         33.0         39.0         69.0
# 222        735.0        66.0         33.0         39.0         69.0
# 109        735.0        66.0         33.0         39.0         69.0
# 110        735.0        66.0         33.0         39.0         69.0
# 221        735.0        66.0         33.0         39.0         69.0
#
#      25-29 years  30-34 years  35-39 years  40-44 years  45-49 years  \
# 86          75.0         69.0         60.0         36.0         45.0
# 222         75.0         69.0         60.0         36.0         45.0
# 109         75.0         69.0         60.0         36.0         45.0
# 110         75.0         69.0         60.0         36.0         45.0
# 221         75.0         69.0         60.0         36.0         45.0
#
#      50-54 years  55-59 years  60-64 years  65-69 years  70-74 years  \
# 86          60.0         57.0         39.0         24.0          9.0
# 222         60.0         57.0         39.0         24.0          9.0
# 109         60.0         57.0         39.0         24.0          9.0
# 110         60.0         57.0         39.0         24.0          9.0
# 221         60.0         57.0         39.0         24.0          9.0
#
#      75-79 years  80-84 years  Median age(17)   Under 15 years  15-29 years  \
# 86          12.0          3.0            64.8            141.0        180.0
# 222         12.0          3.0            64.8            141.0        180.0
# 109         12.0          3.0            64.8            141.0        180.0
# 110         12.0          3.0            64.8            141.0        180.0
# 221         12.0          3.0            64.8            141.0        180.0
#
#      30-64 years  Less than one year  1 year  2 years  3 years  4 years  \
# 86         366.0                21.0    24.0      9.0      3.0     15.0
# 222        366.0                21.0    24.0      9.0      3.0     15.0
# 109        366.0                21.0    24.0      9.0      3.0     15.0
# 110        366.0                21.0    24.0      9.0      3.0     15.0
# 221        366.0                21.0    24.0      9.0      3.0     15.0
#
#      5-9 years  10-19 years  No children  One child  Two children  \
# 86        39.0         33.0         81.0       30.0          36.0
# 222       39.0         33.0         81.0       30.0          36.0
# 109       39.0         33.0         81.0       30.0          36.0
# 110       39.0         33.0         81.0       30.0          36.0
# 221       39.0         33.0         81.0       30.0          36.0
#
#      Three children  Four children  Five children  No qualification  \
# 86             15.0           21.0            3.0              69.0
# 222            15.0           21.0            3.0              69.0
# 109            15.0           21.0            3.0              69.0
# 110            15.0           21.0            3.0              69.0
# 221            15.0           21.0            3.0              69.0
#
#      Level 1 certificate  Level 2 certificate  Level 3 certificate  \
# 86                  42.0                 45.0                 60.0
# 222                 42.0                 45.0                 60.0
# 109                 42.0                 45.0                 60.0
# 110                 42.0                 45.0                 60.0
# 221                 42.0                 45.0                 60.0
#
#      Level 4 certificate  Level 5 diploma  Level 6 diploma  \
# 86                  54.0             18.0             21.0
# 222                 54.0             18.0             21.0
# 109                 54.0             18.0             21.0
# 110                 54.0             18.0             21.0
# 221                 54.0             18.0             21.0
#
#      Bachelor degree and Level 7 qualification  \
# 86                                        72.0
# 222                                       72.0
# 109                                       72.0
# 110                                       72.0
# 221                                       72.0
#
#      Post-graduate and honours degrees  Masters degree  Doctorate degree  \
# 86                                27.0            18.0               3.0
# 222                               27.0            18.0               3.0
# 109                               27.0            18.0               3.0
# 110                               27.0            18.0               3.0
# 221                               27.0            18.0               3.0
#
#      $5,000 or less  $5,001 – $10,000  $10,001 – $20,000  $20,001 – $30,000  \
# 86             78.0              30.0               87.0               69.0
# 222            78.0              30.0               87.0               69.0
# 109            78.0              30.0               87.0               69.0
# 110            78.0              30.0               87.0               69.0
# 221            78.0              30.0               87.0               69.0
#
#      $30,001 – $50,000  $50,001 – $70,000  Median personal income($)  \
# 86               150.0               96.0                    66800.0
# 222              150.0               96.0                    66800.0
# 109              150.0               96.0                    66800.0
# 110              150.0               96.0                    66800.0
# 221              150.0               96.0                    66800.0
#
#      Employed Full time  Employed Part time  Unemployed  \
# 86                351.0                69.0        21.0
# 222               351.0                69.0        21.0
# 109               351.0                69.0        21.0
# 110               351.0                69.0        21.0
# 221               351.0                69.0        21.0
#
#      Not in the Labour Force  Total stated  Managers  Professionals  \
# 86                     153.0         594.0      57.0           90.0
# 222                    153.0         594.0      57.0           90.0
# 109                    153.0         594.0      57.0           90.0
# 110                    153.0         594.0      57.0           90.0
# 221                    153.0         594.0      57.0           90.0
#
#      Technicians and Trades Workers  Community and Personal Service Workers  \
# 86                             45.0                                    42.0
# 222                            45.0                                    42.0
# 109                            45.0                                    42.0
# 110                            45.0                                    42.0
# 221                            45.0                                    42.0
#
#      Clerical and Administrative Workers  Sales Workers  \
# 86                                  51.0           33.0
# 222                                 51.0           33.0
# 109                                 51.0           33.0
# 110                                 51.0           33.0
# 221                                 51.0           33.0
#
#      Machinery Operators and Drivers  Manufacturing  \
# 86                              42.0           45.0
# 222                             42.0           45.0
# 109                             42.0           45.0
# 110                             42.0           45.0
# 221                             42.0           45.0
#
#      Electricity Gas Water and Waste Services  Construction  Wholesale Trade  \
# 86                                        3.0          33.0             18.0
# 222                                       3.0          33.0             18.0
# 109                                       3.0          33.0             18.0
# 110                                       3.0          33.0             18.0
# 221                                       3.0          33.0             18.0
#
#      Retail Trade  Accommodation and Food Services  \
# 86           30.0                             42.0
# 222          30.0                             42.0
# 109          30.0                             42.0
# 110          30.0                             42.0
# 221          30.0                             42.0
#
#      Transport Postal and Warehousing  \
# 86                               48.0
# 222                              48.0
# 109                              48.0
# 110                              48.0
# 221                              48.0
#
#      Information Media and Telecommunications  \
# 86                                        9.0
# 222                                       9.0
# 109                                       9.0
# 110                                       9.0
# 221                                       9.0
#
#      Financial and Insurance Services  Rental Hiring and Real Estate Services  \
# 86                                6.0                                     9.0
# 222                               6.0                                     9.0
# 109                               6.0                                     9.0
# 110                               6.0                                     9.0
# 221                               6.0                                     9.0
#
#      Professional Scientific and Technical Services  \
# 86                                             36.0
# 222                                            36.0
# 109                                            36.0
# 110                                            36.0
# 221                                            36.0
#
#      Administrative and Support Services  Public Administration and Safety  \
# 86                                  21.0                              21.0
# 222                                 21.0                              21.0
# 109                                 21.0                              21.0
# 110                                 21.0                              21.0
# 221                                 21.0                              21.0
#
#      Education and Training  Health Care and Social Assistance  \
# 86                     33.0                               21.0
# 222                    33.0                               21.0
# 109                    33.0                               21.0
# 110                    33.0                               21.0
# 221                    33.0                               21.0
#
#      Arts and Recreation Services  Work at home  \
# 86                           12.0          30.0
# 222                          12.0          30.0
# 109                          12.0          30.0
# 110                          12.0          30.0
# 221                          12.0          30.0
#
#      Drive a private car, truck or van  Drive a company car, truck or van  \
# 86                               120.0                               39.0
# 222                              120.0                               39.0
# 109                              120.0                               39.0
# 110                              120.0                               39.0
# 221                              120.0                               39.0
#
#      Passenger in a car, truck, van or company bus  Train  Bicycle  \
# 86                                             9.0    0.0      3.0
# 222                                            9.0    0.0      3.0
# 109                                            9.0    0.0      3.0
# 110                                            9.0    0.0      3.0
# 221                                            9.0    0.0      3.0
#
#      Walk or jog Area Unit  \
# 86          36.0  Auckland
# 222         36.0  Auckland
# 109         36.0  Auckland
# 110         36.0  Auckland
# 221         36.0  Auckland
#
#      Abduction, Harassment and Other Related Offences Against a Person  \
# 86                                                 1.0
# 222                                                1.0
# 109                                                1.0
# 110                                                1.0
# 221                                                1.0
#
#      Acts Intended to Cause Injury  Robbery, Extortion and Related Offences  \
# 86                           262.0                                     42.0
# 222                          262.0                                     42.0
# 109                          262.0                                     42.0
# 110                          262.0                                     42.0
# 221                          262.0                                     42.0
#
#      Sexual Assault and Related Offences  Theft and Related Offences  \
# 86                                  11.0                      1628.0
# 222                                 11.0                      1628.0
# 109                                 11.0                      1628.0
# 110                                 11.0                      1628.0
# 221                                 11.0                      1628.0
#
#      Unlawful Entry With Intent/Burglary, Break and Enter
# 86                                               219.0
# 222                                              219.0
# 109                                              219.0
# 110                                              219.0
# 221                                              219.0

# %%
df = df.merge(merged_final, left_on='Suburb', right_on='Area_Description', how='left')

# %%
df.drop('Area_Description', axis=1, inplace=True)
df = df.sort_values(by='Suburb')

# %%
df.head()
# Out:
#        Suburb                                            Address  \
# 86   Auckland  9/3 Eden Crescent, Auckland Central, Auckland ...
# 222  Auckland  2B/2 White Street, Auckland Central, Auckland ...
# 109  Auckland  406/138 Anzac Ave, Auckland Central, Auckland ...
# 110  Auckland  121/72 Nelson St , Auckland Central, Auckland ...
# 221  Auckland  72 Nelson Street, Auckland Central, Auckland City
#
#                          Price  Bedroom  Bathroom  Garage Other Feature 1  \
# 86                         620        2         1       1             NaN
# 222  Auckland Central insights        2         1    <NA>            None
# 109                        320        1         1    <NA>       1 ensuite
# 110                        470        2         1    <NA>             NaN
# 221                        375        1         1    <NA>             NaN
#
#     Other Feature 2  Furniture  Type_Apartment  Type_Carpark  Type_House  \
# 86              NaN          0               1             0           0
# 222            None          1               1             0           0
# 109             NaN          0               1             0           0
# 110             NaN          0               1             0           0
# 221             NaN          0               1             0           0
#
#      Type_Studio  Type_Townhouse  Type_Unit  Type_Unknown  2018.0  \
# 86             0               0          0             0   213.0
# 222            0               0          0             0   213.0
# 109            0               0          0             0   213.0
# 110            0               0          0             0   213.0
# 221            0               0          0             0   213.0
#
#      2018 Census   0-4 years  10-14 years  15-19 years  20-24 years  \
# 86         735.0        66.0         33.0         39.0         69.0
# 222        735.0        66.0         33.0         39.0         69.0
# 109        735.0        66.0         33.0         39.0         69.0
# 110        735.0        66.0         33.0         39.0         69.0
# 221        735.0        66.0         33.0         39.0         69.0
#
#      25-29 years  30-34 years  35-39 years  40-44 years  45-49 years  \
# 86          75.0         69.0         60.0         36.0         45.0
# 222         75.0         69.0         60.0         36.0         45.0
# 109         75.0         69.0         60.0         36.0         45.0
# 110         75.0         69.0         60.0         36.0         45.0
# 221         75.0         69.0         60.0         36.0         45.0
#
#      50-54 years  55-59 years  60-64 years  65-69 years  70-74 years  \
# 86          60.0         57.0         39.0         24.0          9.0
# 222         60.0         57.0         39.0         24.0          9.0
# 109         60.0         57.0         39.0         24.0          9.0
# 110         60.0         57.0         39.0         24.0          9.0
# 221         60.0         57.0         39.0         24.0          9.0
#
#      75-79 years  80-84 years  Median age(17)   Under 15 years  15-29 years  \
# 86          12.0          3.0            64.8            141.0        180.0
# 222         12.0          3.0            64.8            141.0        180.0
# 109         12.0          3.0            64.8            141.0        180.0
# 110         12.0          3.0            64.8            141.0        180.0
# 221         12.0          3.0            64.8            141.0        180.0
#
#      30-64 years  Less than one year  1 year  2 years  3 years  4 years  \
# 86         366.0                21.0    24.0      9.0      3.0     15.0
# 222        366.0                21.0    24.0      9.0      3.0     15.0
# 109        366.0                21.0    24.0      9.0      3.0     15.0
# 110        366.0                21.0    24.0      9.0      3.0     15.0
# 221        366.0                21.0    24.0      9.0      3.0     15.0
#
#      5-9 years  10-19 years  No children  One child  Two children  \
# 86        39.0         33.0         81.0       30.0          36.0
# 222       39.0         33.0         81.0       30.0          36.0
# 109       39.0         33.0         81.0       30.0          36.0
# 110       39.0         33.0         81.0       30.0          36.0
# 221       39.0         33.0         81.0       30.0          36.0
#
#      Three children  Four children  Five children  No qualification  \
# 86             15.0           21.0            3.0              69.0
# 222            15.0           21.0            3.0              69.0
# 109            15.0           21.0            3.0              69.0
# 110            15.0           21.0            3.0              69.0
# 221            15.0           21.0            3.0              69.0
#
#      Level 1 certificate  Level 2 certificate  Level 3 certificate  \
# 86                  42.0                 45.0                 60.0
# 222                 42.0                 45.0                 60.0
# 109                 42.0                 45.0                 60.0
# 110                 42.0                 45.0                 60.0
# 221                 42.0                 45.0                 60.0
#
#      Level 4 certificate  Level 5 diploma  Level 6 diploma  \
# 86                  54.0             18.0             21.0
# 222                 54.0             18.0             21.0
# 109                 54.0             18.0             21.0
# 110                 54.0             18.0             21.0
# 221                 54.0             18.0             21.0
#
#      Bachelor degree and Level 7 qualification  \
# 86                                        72.0
# 222                                       72.0
# 109                                       72.0
# 110                                       72.0
# 221                                       72.0
#
#      Post-graduate and honours degrees  Masters degree  Doctorate degree  \
# 86                                27.0            18.0               3.0
# 222                               27.0            18.0               3.0
# 109                               27.0            18.0               3.0
# 110                               27.0            18.0               3.0
# 221                               27.0            18.0               3.0
#
#      $5,000 or less  $5,001 – $10,000  $10,001 – $20,000  $20,001 – $30,000  \
# 86             78.0              30.0               87.0               69.0
# 222            78.0              30.0               87.0               69.0
# 109            78.0              30.0               87.0               69.0
# 110            78.0              30.0               87.0               69.0
# 221            78.0              30.0               87.0               69.0
#
#      $30,001 – $50,000  $50,001 – $70,000  Median personal income($)  \
# 86               150.0               96.0                    66800.0
# 222              150.0               96.0                    66800.0
# 109              150.0               96.0                    66800.0
# 110              150.0               96.0                    66800.0
# 221              150.0               96.0                    66800.0
#
#      Employed Full time  Employed Part time  Unemployed  \
# 86                351.0                69.0        21.0
# 222               351.0                69.0        21.0
# 109               351.0                69.0        21.0
# 110               351.0                69.0        21.0
# 221               351.0                69.0        21.0
#
#      Not in the Labour Force  Total stated  Managers  Professionals  \
# 86                     153.0         594.0      57.0           90.0
# 222                    153.0         594.0      57.0           90.0
# 109                    153.0         594.0      57.0           90.0
# 110                    153.0         594.0      57.0           90.0
# 221                    153.0         594.0      57.0           90.0
#
#      Technicians and Trades Workers  Community and Personal Service Workers  \
# 86                             45.0                                    42.0
# 222                            45.0                                    42.0
# 109                            45.0                                    42.0
# 110                            45.0                                    42.0
# 221                            45.0                                    42.0
#
#      Clerical and Administrative Workers  Sales Workers  \
# 86                                  51.0           33.0
# 222                                 51.0           33.0
# 109                                 51.0           33.0
# 110                                 51.0           33.0
# 221                                 51.0           33.0
#
#      Machinery Operators and Drivers  Manufacturing  \
# 86                              42.0           45.0
# 222                             42.0           45.0
# 109                             42.0           45.0
# 110                             42.0           45.0
# 221                             42.0           45.0
#
#      Electricity Gas Water and Waste Services  Construction  Wholesale Trade  \
# 86                                        3.0          33.0             18.0
# 222                                       3.0          33.0             18.0
# 109                                       3.0          33.0             18.0
# 110                                       3.0          33.0             18.0
# 221                                       3.0          33.0             18.0
#
#      Retail Trade  Accommodation and Food Services  \
# 86           30.0                             42.0
# 222          30.0                             42.0
# 109          30.0                             42.0
# 110          30.0                             42.0
# 221          30.0                             42.0
#
#      Transport Postal and Warehousing  \
# 86                               48.0
# 222                              48.0
# 109                              48.0
# 110                              48.0
# 221                              48.0
#
#      Information Media and Telecommunications  \
# 86                                        9.0
# 222                                       9.0
# 109                                       9.0
# 110                                       9.0
# 221                                       9.0
#
#      Financial and Insurance Services  Rental Hiring and Real Estate Services  \
# 86                                6.0                                     9.0
# 222                               6.0                                     9.0
# 109                               6.0                                     9.0
# 110                               6.0                                     9.0
# 221                               6.0                                     9.0
#
#      Professional Scientific and Technical Services  \
# 86                                             36.0
# 222                                            36.0
# 109                                            36.0
# 110                                            36.0
# 221                                            36.0
#
#      Administrative and Support Services  Public Administration and Safety  \
# 86                                  21.0                              21.0
# 222                                 21.0                              21.0
# 109                                 21.0                              21.0
# 110                                 21.0                              21.0
# 221                                 21.0                              21.0
#
#      Education and Training  Health Care and Social Assistance  \
# 86                     33.0                               21.0
# 222                    33.0                               21.0
# 109                    33.0                               21.0
# 110                    33.0                               21.0
# 221                    33.0                               21.0
#
#      Arts and Recreation Services  Work at home  \
# 86                           12.0          30.0
# 222                          12.0          30.0
# 109                          12.0          30.0
# 110                          12.0          30.0
# 221                          12.0          30.0
#
#      Drive a private car, truck or van  Drive a company car, truck or van  \
# 86                               120.0                               39.0
# 222                              120.0                               39.0
# 109                              120.0                               39.0
# 110                              120.0                               39.0
# 221                              120.0                               39.0
#
#      Passenger in a car, truck, van or company bus  Train  Bicycle  \
# 86                                             9.0    0.0      3.0
# 222                                            9.0    0.0      3.0
# 109                                            9.0    0.0      3.0
# 110                                            9.0    0.0      3.0
# 221                                            9.0    0.0      3.0
#
#      Walk or jog Area Unit  \
# 86          36.0  Auckland
# 222         36.0  Auckland
# 109         36.0  Auckland
# 110         36.0  Auckland
# 221         36.0  Auckland
#
#      Abduction, Harassment and Other Related Offences Against a Person  \
# 86                                                 1.0
# 222                                                1.0
# 109                                                1.0
# 110                                                1.0
# 221                                                1.0
#
#      Acts Intended to Cause Injury  Robbery, Extortion and Related Offences  \
# 86                           262.0                                     42.0
# 222                          262.0                                     42.0
# 109                          262.0                                     42.0
# 110                          262.0                                     42.0
# 221                          262.0                                     42.0
#
#      Sexual Assault and Related Offences  Theft and Related Offences  \
# 86                                  11.0                      1628.0
# 222                                 11.0                      1628.0
# 109                                 11.0                      1628.0
# 110                                 11.0                      1628.0
# 221                                 11.0                      1628.0
#
#      Unlawful Entry With Intent/Burglary, Break and Enter
# 86                                               219.0
# 222                                              219.0
# 109                                              219.0
# 110                                              219.0
# 221                                              219.0

# %%
df.to_csv('prediction.csv', index=False)
